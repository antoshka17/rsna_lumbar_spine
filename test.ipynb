# %%
import pandas as pd
import numpy as np

sub1 = pd.read_csv('submission(7).csv')
sub2 = pd.read_csv('submission(8).csv')

# %%
sub1
# Out:
#                                              row_id  normal_mild  moderate  \
# 0               4003253_spinal_canal_stenosis_l1_l2     0.991844  0.006777
# 1               4003253_spinal_canal_stenosis_l2_l3     0.995986  0.003314
# 2               4003253_spinal_canal_stenosis_l3_l4     0.988507  0.010468
# 3               4003253_spinal_canal_stenosis_l4_l5     0.973206  0.022013
# 4               4003253_spinal_canal_stenosis_l5_s1     0.986263  0.009789
# ...                                             ...          ...       ...
# 49370  4290709089_right_subarticular_stenosis_l1_l2     0.990825  0.007633
# 49371  4290709089_right_subarticular_stenosis_l2_l3     0.983866  0.014945
# 49372  4290709089_right_subarticular_stenosis_l3_l4     0.892462  0.104117
# 49373  4290709089_right_subarticular_stenosis_l4_l5     0.649853  0.324253
# 49374  4290709089_right_subarticular_stenosis_l5_s1     0.849025  0.127461
#
#          severe
# 0      0.001379
# 1      0.000699
# ...

# %%
sub2
# Out:
#                                              row_id  normal_mild  moderate  \
# 0               4003253_spinal_canal_stenosis_l1_l2     0.991842  0.006779
# 1               4003253_spinal_canal_stenosis_l2_l3     0.995982  0.003318
# 2               4003253_spinal_canal_stenosis_l3_l4     0.988507  0.010468
# 3               4003253_spinal_canal_stenosis_l4_l5     0.973227  0.021996
# 4               4003253_spinal_canal_stenosis_l5_s1     0.986256  0.009794
# ...                                             ...          ...       ...
# 49370  4290709089_right_subarticular_stenosis_l1_l2     0.990054  0.008886
# 49371  4290709089_right_subarticular_stenosis_l2_l3     0.972759  0.025161
# 49372  4290709089_right_subarticular_stenosis_l3_l4     0.860664  0.134442
# 49373  4290709089_right_subarticular_stenosis_l4_l5     0.538277  0.422667
# 49374  4290709089_right_subarticular_stenosis_l5_s1     0.796007  0.165318
#
#          severe
# 0      0.001379
# 1      0.000700
# ...

# %%
for row in range(len(sub1)):
    if abs(sub1.iloc[row, 1] - sub2.iloc[row, 1]) > 0.01:
        print(row)
        break
# Out:
# 25

# %%
print(sub2.iloc[1000, 1])
# Out:
# 0.991841733455658

# %%
sub3 = pd.read_csv('submission(9).csv')
sub3
# Out:
#                                              row_id  normal_mild  moderate  \
# 0               4003253_spinal_canal_stenosis_l1_l2     0.991842  0.006779
# 1               4003253_spinal_canal_stenosis_l2_l3     0.995982  0.003318
# 2               4003253_spinal_canal_stenosis_l3_l4     0.988507  0.010468
# 3               4003253_spinal_canal_stenosis_l4_l5     0.973227  0.021996
# 4               4003253_spinal_canal_stenosis_l5_s1     0.986256  0.009794
# ...                                             ...          ...       ...
# 49370  4290709089_right_subarticular_stenosis_l1_l2     0.990825  0.007633
# 49371  4290709089_right_subarticular_stenosis_l2_l3     0.983864  0.014947
# 49372  4290709089_right_subarticular_stenosis_l3_l4     0.892441  0.104137
# 49373  4290709089_right_subarticular_stenosis_l4_l5     0.649855  0.324240
# 49374  4290709089_right_subarticular_stenosis_l5_s1     0.848996  0.127493
#
#          severe
# 0      0.001379
# 1      0.000700
# ...

# %%
for row in range(len(sub1)):
    if abs(sub1.iloc[row, 1] - sub3.iloc[row, 1]) > 0.01:
        print(row)
        break

# %%
'ok'
# Out:
# 'ok'

# %%
import torch
import timm

timm.create_model(
        'densenet161',
        pretrained=True, 
        features_only=False,
        in_chans=48,
        num_classes=75,
        global_pool='avg'
)
# Out:
# /home/anton/anaconda3/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/anton/anaconda3/lib/python3.11/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(48, 96, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNormAct2d(
#       96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#       (drop): Identity()
#       (act): ReLU(inplace=True)
#     )
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): DenseBlock(
#       (denselayer1): DenseLayer(
# ...

# %%
import os
rd = 'rsna-2024-lumbar-spine-degenerative-classification'
coords = pd.read_csv(os.path.join(rd, 'train_label_coordinates.csv'))
coords
# Out:
#          study_id   series_id  instance_number  \
# 0         4003253   702807833                8
# 1         4003253   702807833                8
# 2         4003253   702807833                8
# 3         4003253   702807833                8
# 4         4003253   702807833                8
# ...           ...         ...              ...
# 48687  4290709089  4237840455               11
# 48688  4290709089  4237840455               12
# 48689  4290709089  4237840455               12
# 48690  4290709089  4237840455               12
# 48691  4290709089  4237840455               12
#
#                              condition  level           x           y
# 0                Spinal Canal Stenosis  L1/L2  322.831858  227.964602
# 1                Spinal Canal Stenosis  L2/L3  320.571429  295.714286
# 2                Spinal Canal Stenosis  L3/L4  323.030303  371.818182
# 3                Spinal Canal Stenosis  L4/L5  335.292035  427.327434
# ...

# %%
fns = set()
sis = set()
for i in range(len(coords)):
    study_id = coords.iloc[i, 0]
    series_id = coords.iloc[i, 1]
    num = coords.iloc[i, 2]
    fns.add(str(study_id) + '_' + str(series_id) + '_' + str(num))
    sis.add(study_id)
len(fns)
# Out:
# 24546

# %%
len(sis)
# Out:
# 1974
