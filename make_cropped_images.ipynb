# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
import os, sys
import glob
import math
import cv2
from PIL import Image
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from pathlib import Path
import matplotlib.pyplot as plt
# Out:
# /home/anton/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
detection_model = torchvision.models.detection.fasterrcnn_mobilenet_v3_large_320_fpn(pretrained=False, pretrained_backbone=False)
num_classes = 6

in_features = detection_model.roi_heads.box_predictor.cls_score.in_features
detection_model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

detection_model.load_state_dict(torch.load('detection_model.pt'))
detection_model = detection_model.to(device)
# Out:
# /home/anton/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/anton/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /home/anton/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained_backbone' is deprecated since 0.13 and may be removed in the future, please use 'weights_backbone' instead.
#   warnings.warn(
# /home/anton/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights_backbone' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights_backbone=None`.
#   warnings.warn(msg)

# %%
cropped_images_dir = 'cropped_images'
cropped_images_detailed_dir = 'cropped_images_detailed'
if not Path(cropped_images_dir).exists():
    os.mkdir(cropped_images_dir)
    
if not Path(cropped_images_detailed_dir).exists():
    os.mkdir(cropped_images_detailed_dir)

# %%
train_images_dir = 'cvt_png'
all_files = glob.glob(f'{train_images_dir}/*/*/*.png')
all_files.sort()
all_files[:5]
# Out:
# ['cvt_png/100206310/Axial T2/000.png',
#  'cvt_png/100206310/Axial T2/001.png',
#  'cvt_png/100206310/Axial T2/002.png',
#  'cvt_png/100206310/Axial T2/003.png',
#  'cvt_png/100206310/Axial T2/004.png']

# %%
detection_model.eval()
counters = {'_'.join(image_path.split('/')[1:3]):0 for image_path in tqdm(all_files)}
df_boxes = pd.DataFrame()
dir_levels_cnts = {}
bbx1, bbx2, bby1, bby2, fns, all_levels = [], [], [], [], [], []

i_to_level = {1: 'L1/L2', 2: 'L2/L3', 3: 'L3/L4', 4: 'L4/L5', 5: 'L5/S1'}

for image_path in tqdm(all_files):
    splitted = image_path.split('/')
    si, typ = splitted[1], splitted[2]
    if typ != 'Sagittal T1':
        continue
    if not Path(os.path.join(cropped_images_dir, si)).exists():
        os.mkdir(os.path.join(cropped_images_dir, si))
        
    if not Path(os.path.join(cropped_images_dir, si, typ)).exists():
        os.mkdir(os.path.join(cropped_images_dir, si, typ))
        
    if not Path(os.path.join(cropped_images_detailed_dir, si)).exists():
        os.mkdir(os.path.join(cropped_images_detailed_dir, si))
        
    if not Path(os.path.join(cropped_images_detailed_dir, si, typ)).exists():
        os.mkdir(os.path.join(cropped_images_detailed_dir, si, typ))
        
    image_t = cv2.imread(image_path).astype(np.float32)
    image = image_t / 255.0
    image = torch.tensor(image).permute(2, 0, 1).unsqueeze(0).to(device)
    
    boxes, levels = [], []
    with torch.no_grad():
        predictions = detection_model(image)
        
        for i in range(len(predictions)):
            for box in predictions[i]['boxes'].detach().cpu().numpy():
                boxes.append(box)
                
        for i in range(len(predictions)):
            for level in predictions[i]['labels'].detach().cpu().numpy():
                levels.append(i_to_level[level])
                all_levels.append(i_to_level[level])
                
    
    for box in boxes:
        bbx1.append(int(box[0]))
        bbx2.append(int(box[2]))
        bby1.append(int(box[1]))
        bby2.append(int(box[3]))
        fns.append(image_path)
        
#     for box in boxes:
#         image_t = cv2.rectangle(image_t, (int(box[0]), int(box[1])), (int(box[2]), int(box[3])), (255, 255, 255))
        
#     cv2.imwrite('test.png', image_t)
#     image_t = Image.open('test.png').convert('L')
#     plt.imshow(image_t)
#     plt.show()
    for i, box in enumerate(boxes):
        image_cropped = image_t[int(box[1]):int(box[3]), int(box[0]):int(box[2])]
        image_cropped = cv2.resize(image_cropped, (192, 192))
        level = '_'.join(levels[i].split('/'))
        
        dir_level = os.path.join(cropped_images_detailed_dir, str(si), str(typ), level)
        if not Path(dir_level).exists():
            os.mkdir(dir_level)
            dir_levels_cnts[dir_level] = 0
        
        new_level_image_path = os.path.join(dir_level, 
            (3 - len(str(dir_levels_cnts[dir_level]))) * '0' + str(dir_levels_cnts[dir_level]) + '.png')
        new_image_path = os.path.join(cropped_images_dir, str(si), str(typ),
                (3 - len(str(counters[str(si)+'_'+str(typ)]))) * '0' + str(counters[str(si)+'_'+str(typ)]) + '.png')

        counters[str(si)+'_'+str(typ)] += 1
        dir_levels_cnts[dir_level] += 1
        
        cv2.imwrite(new_image_path, image_cropped)
        cv2.imwrite(new_level_image_path, image_cropped)

df_boxes['filename'] = fns
df_boxes['x1'] = bbx1
df_boxes['y1'] = bby1
df_boxes['x2'] = bbx2
df_boxes['y2'] = bby2
df_boxes['level'] = all_levels
df_boxes.to_csv('boxes.csv', index=False)
# Out:
#   0%|          | 0/147218 [00:00<?, ?it/s]
#   0%|          | 0/147218 [00:00<?, ?it/s]

# %%
dir_levels_cnts
# Out:
# {'cropped_images_detailed/100206310/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/100206310/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/100206310/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/100206310/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/100206310/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1002894806/Sagittal T1/L5_S1': 19,
#  'cropped_images_detailed/1002894806/Sagittal T1/L4_L5': 14,
#  'cropped_images_detailed/1002894806/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1002894806/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1002894806/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1004726367/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1004726367/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1004726367/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1004726367/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1004726367/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1008446160/Sagittal T1/L5_S1': 7,
#  'cropped_images_detailed/1008446160/Sagittal T1/L4_L5': 4,
#  'cropped_images_detailed/1008446160/Sagittal T1/L2_L3': 2,
#  'cropped_images_detailed/1008446160/Sagittal T1/L3_L4': 2,
#  'cropped_images_detailed/1008446160/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1009445512/Sagittal T1/L1_L2': 12,
#  'cropped_images_detailed/1009445512/Sagittal T1/L2_L3': 10,
#  'cropped_images_detailed/1009445512/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1009445512/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1009445512/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1009905322/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1009905322/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1009905322/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1009905322/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1009905322/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1012375618/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1012375618/Sagittal T1/L4_L5': 5,
#  'cropped_images_detailed/1012375618/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1012375618/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1012375618/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1013589491/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1013589491/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1013589491/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1013589491/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1013589491/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1013791258/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1013791258/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1013791258/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1013791258/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1013791258/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1018005303/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1018005303/Sagittal T1/L4_L5': 14,
#  'cropped_images_detailed/1018005303/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1018005303/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1018005303/Sagittal T1/L1_L2': 3,
#  'cropped_images_detailed/1019430579/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1019430579/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1019430579/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1019430579/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1019430579/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1020394063/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1020394063/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1020394063/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1020394063/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1020394063/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1025265129/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1025265129/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1025265129/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1025265129/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1025265129/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1028684462/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1028684462/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1028684462/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1028684462/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1028684462/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1028909382/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1028909382/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1028909382/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1028909382/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1028909382/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1035170868/Sagittal T1/L1_L2': 11,
#  'cropped_images_detailed/1035170868/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1035170868/Sagittal T1/L2_L3': 14,
#  'cropped_images_detailed/1035170868/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/1035170868/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1036203708/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1036203708/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1036203708/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1036203708/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1036203708/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1038453736/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1038453736/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1038453736/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1038453736/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1038453736/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1039182563/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1039182563/Sagittal T1/L4_L5': 13,
#  'cropped_images_detailed/1039182563/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1039182563/Sagittal T1/L1_L2': 3,
#  'cropped_images_detailed/1039182563/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1040921274/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1040921274/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1040921274/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1040921274/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1040921274/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1047914296/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1047914296/Sagittal T1/L4_L5': 14,
#  'cropped_images_detailed/1047914296/Sagittal T1/L3_L4': 11,
#  'cropped_images_detailed/1047914296/Sagittal T1/L2_L3': 11,
#  'cropped_images_detailed/1047914296/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1050200728/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1050200728/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1050200728/Sagittal T1/L5_S1': 5,
#  'cropped_images_detailed/1050200728/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1050200728/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1051198661/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1051198661/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1051198661/Sagittal T1/L2_L3': 10,
#  'cropped_images_detailed/1051198661/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/1051198661/Sagittal T1/L1_L2': 12,
#  'cropped_images_detailed/1051595826/Sagittal T1/L5_S1': 16,
#  'cropped_images_detailed/1051595826/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1051595826/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1051595826/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1051595826/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1051657831/Sagittal T1/L2_L3': 13,
#  'cropped_images_detailed/1051657831/Sagittal T1/L1_L2': 10,
#  'cropped_images_detailed/1051657831/Sagittal T1/L5_S1': 7,
#  'cropped_images_detailed/1051657831/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1051657831/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1057173941/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1057173941/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1057173941/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1057173941/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1057173941/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/105895264/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/105895264/Sagittal T1/L4_L5': 15,
#  'cropped_images_detailed/105895264/Sagittal T1/L3_L4': 12,
#  'cropped_images_detailed/105895264/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/105895264/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/106310815/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/106310815/Sagittal T1/L3_L4': 11,
#  'cropped_images_detailed/106310815/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/106310815/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/106310815/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/10728036/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/10728036/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/10728036/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/10728036/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/10728036/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1075351916/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1075351916/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1075351916/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1075351916/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1075351916/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1075863395/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1075863395/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1075863395/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1075863395/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1075863395/Sagittal T1/L1_L2': 2,
#  'cropped_images_detailed/107698245/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/107698245/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/107698245/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/107698245/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/107698245/Sagittal T1/L2_L3': 1,
#  'cropped_images_detailed/1078357909/Sagittal T1/L5_S1': 7,
#  'cropped_images_detailed/1078357909/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1078357909/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/1078357909/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1078357909/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/107935613/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/107935613/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/107935613/Sagittal T1/L3_L4': 1,
#  'cropped_images_detailed/107935613/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/107935613/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1079625817/Sagittal T1/L5_S1': 7,
#  'cropped_images_detailed/1079625817/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1079625817/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1079625817/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1079625817/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1082591956/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1082591956/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1082591956/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1082591956/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1082591956/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1082665764/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1082665764/Sagittal T1/L5_S1': 16,
#  'cropped_images_detailed/1082665764/Sagittal T1/L4_L5': 15,
#  'cropped_images_detailed/1082665764/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1082665764/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/108348787/Sagittal T1/L5_S1': 21,
#  'cropped_images_detailed/108348787/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/108348787/Sagittal T1/L1_L2': 10,
#  'cropped_images_detailed/108348787/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/108348787/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1084486898/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/1084486898/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1084486898/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1084486898/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1084486898/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1085426528/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/1085426528/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1085426528/Sagittal T1/L4_L5': 13,
#  'cropped_images_detailed/1085426528/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1085426528/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1086363712/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1086363712/Sagittal T1/L4_L5': 14,
#  'cropped_images_detailed/1086363712/Sagittal T1/L3_L4': 12,
#  'cropped_images_detailed/1086363712/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1086363712/Sagittal T1/L1_L2': 1,
#  'cropped_images_detailed/1087298370/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1087298370/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1087298370/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1087298370/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1087298370/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1088270559/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1088270559/Sagittal T1/L4_L5': 16,
#  'cropped_images_detailed/1088270559/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1088270559/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1088270559/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1093392148/Sagittal T1/L4_L5': 20,
#  'cropped_images_detailed/1093392148/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1093392148/Sagittal T1/L3_L4': 11,
#  'cropped_images_detailed/1093392148/Sagittal T1/L2_L3': 10,
#  'cropped_images_detailed/1093392148/Sagittal T1/L1_L2': 11,
#  'cropped_images_detailed/109454808/Sagittal T1/L5_S1': 20,
#  'cropped_images_detailed/109454808/Sagittal T1/L4_L5': 16,
#  'cropped_images_detailed/109454808/Sagittal T1/L3_L4': 13,
#  'cropped_images_detailed/109454808/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/109454808/Sagittal T1/L2_L3': 11,
#  'cropped_images_detailed/1094670148/Sagittal T1/L5_S1': 16,
#  'cropped_images_detailed/1094670148/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1094670148/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1094670148/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1094670148/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1094879459/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1094879459/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1094879459/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1094879459/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1094879459/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1095894979/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1095894979/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1095894979/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1095894979/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1095894979/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1096630192/Sagittal T1/L4_L5': 16,
#  'cropped_images_detailed/1096630192/Sagittal T1/L3_L4': 14,
#  'cropped_images_detailed/1096630192/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1096630192/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1096630192/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/109677683/Sagittal T1/L4_L5': 19,
#  'cropped_images_detailed/109677683/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/109677683/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/109677683/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/109677683/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1097875334/Sagittal T1/L5_S1': 6,
#  'cropped_images_detailed/1097875334/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1097875334/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1097875334/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1097875334/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1099112122/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1099112122/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1099112122/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1099112122/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1099112122/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/110271740/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/110271740/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/110271740/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/110271740/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/110271740/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1103373889/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1103373889/Sagittal T1/L5_S1': 7,
#  'cropped_images_detailed/1103373889/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1103373889/Sagittal T1/L2_L3': 2,
#  'cropped_images_detailed/1103373889/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1104422628/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1104422628/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1104422628/Sagittal T1/L3_L4': 2,
#  'cropped_images_detailed/1104422628/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1104422628/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1105006429/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1105006429/Sagittal T1/L2_L3': 11,
#  'cropped_images_detailed/1105006429/Sagittal T1/L5_S1': 6,
#  'cropped_images_detailed/1105006429/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1105006429/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1106510276/Sagittal T1/L4_L5': 14,
#  'cropped_images_detailed/1106510276/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1106510276/Sagittal T1/L3_L4': 12,
#  'cropped_images_detailed/1106510276/Sagittal T1/L1_L2': 10,
#  'cropped_images_detailed/1106510276/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1115481506/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1115481506/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1115481506/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1115481506/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1115481506/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1115952008/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1115952008/Sagittal T1/L4_L5': 15,
#  'cropped_images_detailed/1115952008/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/1115952008/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1115952008/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1116588610/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1116588610/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1116588610/Sagittal T1/L5_S1': 20,
#  'cropped_images_detailed/1116588610/Sagittal T1/L4_L5': 16,
#  'cropped_images_detailed/1116588610/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/111701877/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/111701877/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/111701877/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/111701877/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/111701877/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1117361192/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1117361192/Sagittal T1/L4_L5': 5,
#  'cropped_images_detailed/1117361192/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1117361192/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1117361192/Sagittal T1/L1_L2': 3,
#  'cropped_images_detailed/1117492266/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1117492266/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1117492266/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1117492266/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1117492266/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1119763924/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1119763924/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1119763924/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1119763924/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1119763924/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1121141304/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1121141304/Sagittal T1/L4_L5': 13,
#  'cropped_images_detailed/1121141304/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1121141304/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1121141304/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/112166434/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/112166434/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/112166434/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/112166434/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/112166434/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/1123923932/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1123923932/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1123923932/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1123923932/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1123923932/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1125605580/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1125605580/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1125605580/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/1125605580/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1125605580/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1125872530/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1125872530/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1125872530/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1125872530/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1125872530/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1130460319/Sagittal T1/L4_L5': 15,
#  'cropped_images_detailed/1130460319/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1130460319/Sagittal T1/L3_L4': 17,
#  'cropped_images_detailed/1130460319/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1130460319/Sagittal T1/L2_L3': 11,
#  'cropped_images_detailed/1130601231/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1130601231/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1130601231/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1130601231/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1130601231/Sagittal T1/L3_L4': 1,
#  'cropped_images_detailed/113121178/Sagittal T1/L5_S1': 19,
#  'cropped_images_detailed/113121178/Sagittal T1/L4_L5': 15,
#  'cropped_images_detailed/113121178/Sagittal T1/L3_L4': 13,
#  'cropped_images_detailed/113121178/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/113121178/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1132297038/Sagittal T1/L5_S1': 16,
#  'cropped_images_detailed/1132297038/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1132297038/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1132297038/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1132297038/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1133001306/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1133001306/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1133001306/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1133001306/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1133001306/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1133158151/Sagittal T1/L5_S1': 6,
#  'cropped_images_detailed/1133158151/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1133158151/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1133158151/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1133158151/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/11340341/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/11340341/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/11340341/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/11340341/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/11340341/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/113758629/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/113758629/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/113758629/Sagittal T1/L3_L4': 11,
#  'cropped_images_detailed/113758629/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/113758629/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1140449293/Sagittal T1/L2_L3': 13,
#  'cropped_images_detailed/1140449293/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1140449293/Sagittal T1/L1_L2': 14,
#  'cropped_images_detailed/1140449293/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1140449293/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1140848367/Sagittal T1/L5_S1': 7,
#  'cropped_images_detailed/1140848367/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1140848367/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1140848367/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1140848367/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1140988368/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1140988368/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1140988368/Sagittal T1/L1_L2': 10,
#  'cropped_images_detailed/1140988368/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1140988368/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1142910752/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1142910752/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1142910752/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1142910752/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1142910752/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1143209760/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1143209760/Sagittal T1/L4_L5': 14,
#  'cropped_images_detailed/1143209760/Sagittal T1/L3_L4': 11,
#  'cropped_images_detailed/1143209760/Sagittal T1/L2_L3': 13,
#  'cropped_images_detailed/1143209760/Sagittal T1/L1_L2': 12,
#  'cropped_images_detailed/1143931807/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1143931807/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1143931807/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1143931807/Sagittal T1/L1_L2': 2,
#  'cropped_images_detailed/1143931807/Sagittal T1/L2_L3': 2,
#  'cropped_images_detailed/1144816961/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1144816961/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1144816961/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1144816961/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1144816961/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1145017084/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1145017084/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1145017084/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1145017084/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1145017084/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/114899184/Sagittal T1/L5_S1': 18,
#  'cropped_images_detailed/114899184/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/114899184/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/114899184/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/114899184/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1153238977/Sagittal T1/L5_S1': 17,
#  'cropped_images_detailed/1153238977/Sagittal T1/L4_L5': 16,
#  'cropped_images_detailed/1153238977/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1153238977/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1153238977/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/115990621/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/115990621/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/115990621/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/115990621/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/115990621/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1164861071/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1164861071/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1164861071/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1164861071/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1164861071/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1165361924/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1165361924/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1165361924/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1165361924/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1165361924/Sagittal T1/L1_L2': 3,
#  'cropped_images_detailed/1166421944/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1166421944/Sagittal T1/L4_L5': 2,
#  'cropped_images_detailed/1166421944/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1166421944/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1166421944/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1167650541/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1167650541/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1167650541/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1167650541/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1167650541/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1169119083/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1169119083/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1169119083/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1169119083/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1169119083/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1171797088/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1171797088/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1171797088/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1171797088/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1171797088/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1172644546/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1172644546/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1172644546/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1172644546/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1172644546/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1176604093/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1176604093/Sagittal T1/L4_L5': 14,
#  'cropped_images_detailed/1176604093/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/1176604093/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1176604093/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1176954132/Sagittal T1/L5_S1': 20,
#  'cropped_images_detailed/1176954132/Sagittal T1/L4_L5': 18,
#  'cropped_images_detailed/1176954132/Sagittal T1/L1_L2': 10,
#  'cropped_images_detailed/1176954132/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1176954132/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/117720278/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/117720278/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/117720278/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/117720278/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/117720278/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1178209527/Sagittal T1/L5_S1': 22,
#  'cropped_images_detailed/1178209527/Sagittal T1/L4_L5': 17,
#  'cropped_images_detailed/1178209527/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/1178209527/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1178209527/Sagittal T1/L1_L2': 3,
#  'cropped_images_detailed/1179643011/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1179643011/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1179643011/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1179643011/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1179643011/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1180134227/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1180134227/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1180134227/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1180134227/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1180134227/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1187463765/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1187463765/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1187463765/Sagittal T1/L1_L2': 10,
#  'cropped_images_detailed/1187463765/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1187463765/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1190473557/Sagittal T1/L4_L5': 15,
#  'cropped_images_detailed/1190473557/Sagittal T1/L5_S1': 16,
#  'cropped_images_detailed/1190473557/Sagittal T1/L3_L4': 11,
#  'cropped_images_detailed/1190473557/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1190473557/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/11943292/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/11943292/Sagittal T1/L4_L5': 5,
#  'cropped_images_detailed/11943292/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/11943292/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/11943292/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1195223045/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1195223045/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1195223045/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/1195223045/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1195223045/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1195410745/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1195410745/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1195410745/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1195410745/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1195410745/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1196781988/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1196781988/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1196781988/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1196781988/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1196781988/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1199116491/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1199116491/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1199116491/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1199116491/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1199116491/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1205664021/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1205664021/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1205664021/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1205664021/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1205664021/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1208228762/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1208228762/Sagittal T1/L4_L5': 3,
#  'cropped_images_detailed/1208228762/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1208228762/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1208228762/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1211350060/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1211350060/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1211350060/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1211350060/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1211350060/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1212820061/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1212820061/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1212820061/Sagittal T1/L5_S1': 7,
#  'cropped_images_detailed/1212820061/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1212820061/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1212932624/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1212932624/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1212932624/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/1212932624/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1212932624/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1215498865/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1215498865/Sagittal T1/L4_L5': 4,
#  'cropped_images_detailed/1215498865/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1215498865/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1215498865/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1217004843/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1217004843/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1217004843/Sagittal T1/L3_L4': 12,
#  'cropped_images_detailed/1217004843/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1217004843/Sagittal T1/L2_L3': 10,
#  'cropped_images_detailed/1217477368/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1217477368/Sagittal T1/L4_L5': 14,
#  'cropped_images_detailed/1217477368/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1217477368/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1217477368/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1228406967/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1228406967/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1228406967/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1228406967/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1228406967/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/123154253/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/123154253/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/123154253/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/123154253/Sagittal T1/L2_L3': 13,
#  'cropped_images_detailed/123154253/Sagittal T1/L1_L2': 11,
#  'cropped_images_detailed/1235452314/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1235452314/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1235452314/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/1235452314/Sagittal T1/L2_L3': 12,
#  'cropped_images_detailed/1235452314/Sagittal T1/L1_L2': 11,
#  'cropped_images_detailed/1237708996/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1237708996/Sagittal T1/L4_L5': 4,
#  'cropped_images_detailed/1237708996/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1237708996/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1237708996/Sagittal T1/L3_L4': 1,
#  'cropped_images_detailed/1239697165/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1239697165/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1239697165/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1239697165/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1239697165/Sagittal T1/L1_L2': 3,
#  'cropped_images_detailed/1245057921/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1245057921/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1245057921/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1245057921/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1245057921/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1246624345/Sagittal T1/L5_S1': 25,
#  'cropped_images_detailed/1246624345/Sagittal T1/L4_L5': 16,
#  'cropped_images_detailed/1246624345/Sagittal T1/L3_L4': 12,
#  'cropped_images_detailed/1246624345/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1246624345/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1246626043/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1246626043/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1246626043/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/1246626043/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1246626043/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1246802434/Sagittal T1/L5_S1': 18,
#  'cropped_images_detailed/1246802434/Sagittal T1/L4_L5': 16,
#  'cropped_images_detailed/1246802434/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1246802434/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1246802434/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1249090513/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1249090513/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1249090513/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1249090513/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1249090513/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1249823324/Sagittal T1/L4_L5': 13,
#  'cropped_images_detailed/1249823324/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1249823324/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1249823324/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1249823324/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1253598263/Sagittal T1/L5_S1': 16,
#  'cropped_images_detailed/1253598263/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1253598263/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1253598263/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1253598263/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1254175796/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1254175796/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1254175796/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1254175796/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1254175796/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1255232732/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1255232732/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1255232732/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1255232732/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1255232732/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1258848546/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1258848546/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1258848546/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/1258848546/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1258848546/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1259922642/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1259922642/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1259922642/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1259922642/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1259922642/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1261271580/Sagittal T1/L5_S1': 17,
#  'cropped_images_detailed/1261271580/Sagittal T1/L4_L5': 22,
#  'cropped_images_detailed/1261271580/Sagittal T1/L1_L2': 10,
#  'cropped_images_detailed/1261271580/Sagittal T1/L2_L3': 10,
#  'cropped_images_detailed/1261271580/Sagittal T1/L3_L4': 24,
#  'cropped_images_detailed/1266610368/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1266610368/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1266610368/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1266610368/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1266610368/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1266853322/Sagittal T1/L4_L5': 14,
#  'cropped_images_detailed/1266853322/Sagittal T1/L5_S1': 18,
#  'cropped_images_detailed/1266853322/Sagittal T1/L2_L3': 11,
#  'cropped_images_detailed/1266853322/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1266853322/Sagittal T1/L1_L2': 10,
#  'cropped_images_detailed/1268470656/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1268470656/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1268470656/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1268470656/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1268470656/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1268523032/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1268523032/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1268523032/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1268523032/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1268523032/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1269542152/Sagittal T1/L5_S1': 7,
#  'cropped_images_detailed/1269542152/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1269542152/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1269542152/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1269542152/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1269700501/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1269700501/Sagittal T1/L1_L2': 13,
#  'cropped_images_detailed/1269700501/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1269700501/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1269700501/Sagittal T1/L3_L4': 2,
#  'cropped_images_detailed/1271033295/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/1271033295/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1271033295/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1271033295/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1271033295/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1271819130/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1271819130/Sagittal T1/L4_L5': 13,
#  'cropped_images_detailed/1271819130/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/1271819130/Sagittal T1/L2_L3': 11,
#  'cropped_images_detailed/1271819130/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1274086910/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1274086910/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1274086910/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1274086910/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1274086910/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1274237866/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1274237866/Sagittal T1/L4_L5': 18,
#  'cropped_images_detailed/1274237866/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1274237866/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1274237866/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1277947572/Sagittal T1/L1_L2': 14,
#  'cropped_images_detailed/1277947572/Sagittal T1/L2_L3': 13,
#  'cropped_images_detailed/1277947572/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1277947572/Sagittal T1/L4_L5': 13,
#  'cropped_images_detailed/1277947572/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1278694021/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1278694021/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1278694021/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1278694021/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1278694021/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/128125626/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/128125626/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/128125626/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/128125626/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/128125626/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1286671775/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1286671775/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1286671775/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1286671775/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1286671775/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1288134514/Sagittal T1/L1_L2': 11,
#  'cropped_images_detailed/1288134514/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1288134514/Sagittal T1/L5_S1': 7,
#  'cropped_images_detailed/1288134514/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1288134514/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1289563234/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1289563234/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1289563234/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1289563234/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1289563234/Sagittal T1/L1_L2': 3,
#  'cropped_images_detailed/1291515204/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1291515204/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1291515204/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1291515204/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1291515204/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1292979992/Sagittal T1/L5_S1': 20,
#  'cropped_images_detailed/1292979992/Sagittal T1/L4_L5': 17,
#  'cropped_images_detailed/1292979992/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1292979992/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1292979992/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1294500604/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1294500604/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1294500604/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1294500604/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1294500604/Sagittal T1/L2_L3': 2,
#  'cropped_images_detailed/1296715983/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1296715983/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1296715983/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1296715983/Sagittal T1/L2_L3': 2,
#  'cropped_images_detailed/1296715983/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1298611933/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1298611933/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1298611933/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1298611933/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1298611933/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1301627154/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1301627154/Sagittal T1/L4_L5': 14,
#  'cropped_images_detailed/1301627154/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1301627154/Sagittal T1/L2_L3': 11,
#  'cropped_images_detailed/1301627154/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1301870218/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1301870218/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1301870218/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1301870218/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1301870218/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1302048123/Sagittal T1/L5_S1': 18,
#  'cropped_images_detailed/1302048123/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1302048123/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/1302048123/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1302048123/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1302135990/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1302135990/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1302135990/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1302135990/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1302135990/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1302724340/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1302724340/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1302724340/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1302724340/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1302724340/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/1303408562/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1303408562/Sagittal T1/L4_L5': 13,
#  'cropped_images_detailed/1303408562/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1303408562/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1303408562/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1303767813/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1303767813/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1303767813/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1303767813/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1303767813/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1304643943/Sagittal T1/L5_S1': 16,
#  'cropped_images_detailed/1304643943/Sagittal T1/L4_L5': 16,
#  'cropped_images_detailed/1304643943/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1304643943/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1304643943/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1307819508/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1307819508/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1307819508/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1307819508/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1307819508/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1307961168/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1307961168/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1307961168/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1307961168/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1307961168/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1314603564/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1314603564/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1314603564/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1314603564/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1314603564/Sagittal T1/L1_L2': 3,
#  'cropped_images_detailed/1316926688/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1316926688/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1316926688/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1316926688/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1316926688/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1324569502/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1324569502/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1324569502/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1324569502/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1324569502/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/13317052/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/13317052/Sagittal T1/L4_L5': 5,
#  'cropped_images_detailed/13317052/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/13317052/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/13317052/Sagittal T1/L3_L4': 2,
#  'cropped_images_detailed/1332176994/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1332176994/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1332176994/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/1332176994/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1332176994/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1334624436/Sagittal T1/L3_L4': 11,
#  'cropped_images_detailed/1334624436/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1334624436/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1334624436/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1334624436/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1336036658/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1336036658/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1336036658/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1336036658/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1336036658/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1336127283/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1336127283/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1336127283/Sagittal T1/L4_L5': 13,
#  'cropped_images_detailed/1336127283/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1336127283/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1336412861/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1336412861/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1336412861/Sagittal T1/L3_L4': 11,
#  'cropped_images_detailed/1336412861/Sagittal T1/L2_L3': 9,
#  'cropped_images_detailed/1336412861/Sagittal T1/L1_L2': 10,
#  'cropped_images_detailed/1341339532/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1341339532/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1341339532/Sagittal T1/L4_L5': 5,
#  'cropped_images_detailed/1341339532/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/1341339532/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1344807906/Sagittal T1/L5_S1': 17,
#  'cropped_images_detailed/1344807906/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1344807906/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1344807906/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1344807906/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1346363777/Sagittal T1/L5_S1': 18,
#  'cropped_images_detailed/1346363777/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1346363777/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1346363777/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1346363777/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1347125628/Sagittal T1/L5_S1': 11,
#  'cropped_images_detailed/1347125628/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1347125628/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/1347125628/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1347125628/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1348555135/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1348555135/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1348555135/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1348555135/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1348555135/Sagittal T1/L3_L4': 6,
#  'cropped_images_detailed/135073898/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/135073898/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/135073898/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/135073898/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/135073898/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1353517692/Sagittal T1/L5_S1': 18,
#  'cropped_images_detailed/1353517692/Sagittal T1/L4_L5': 15,
#  'cropped_images_detailed/1353517692/Sagittal T1/L2_L3': 10,
#  'cropped_images_detailed/1353517692/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1353517692/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1354411109/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1354411109/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1354411109/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1354411109/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1354411109/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1360027517/Sagittal T1/L4_L5': 13,
#  'cropped_images_detailed/1360027517/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1360027517/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1360027517/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1360027517/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1365152406/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1365152406/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1365152406/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/1365152406/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1365152406/Sagittal T1/L2_L3': 7,
#  'cropped_images_detailed/1367214681/Sagittal T1/L5_S1': 14,
#  'cropped_images_detailed/1367214681/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1367214681/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1367214681/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1367214681/Sagittal T1/L3_L4': 4,
#  'cropped_images_detailed/1367470327/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1367470327/Sagittal T1/L4_L5': 14,
#  'cropped_images_detailed/1367470327/Sagittal T1/L3_L4': 8,
#  'cropped_images_detailed/1367470327/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1367470327/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1373010257/Sagittal T1/L3_L4': 11,
#  'cropped_images_detailed/1373010257/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1373010257/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1373010257/Sagittal T1/L5_S1': 7,
#  'cropped_images_detailed/1373010257/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1375057718/Sagittal T1/L2_L3': 11,
#  'cropped_images_detailed/1375057718/Sagittal T1/L1_L2': 9,
#  'cropped_images_detailed/1375057718/Sagittal T1/L3_L4': 10,
#  'cropped_images_detailed/1375057718/Sagittal T1/L4_L5': 11,
#  'cropped_images_detailed/1375057718/Sagittal T1/L5_S1': 8,
#  'cropped_images_detailed/1375978793/Sagittal T1/L4_L5': 18,
#  'cropped_images_detailed/1375978793/Sagittal T1/L3_L4': 15,
#  'cropped_images_detailed/1375978793/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1375978793/Sagittal T1/L2_L3': 11,
#  'cropped_images_detailed/1375978793/Sagittal T1/L1_L2': 3,
#  'cropped_images_detailed/1378385941/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1378385941/Sagittal T1/L4_L5': 12,
#  'cropped_images_detailed/1378385941/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1378385941/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1378385941/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1382379752/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1382379752/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1382379752/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1382379752/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1382379752/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1382905170/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1382905170/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1382905170/Sagittal T1/L3_L4': 2,
#  'cropped_images_detailed/1382905170/Sagittal T1/L1_L2': 6,
#  'cropped_images_detailed/1382905170/Sagittal T1/L2_L3': 4,
#  'cropped_images_detailed/1382950184/Sagittal T1/L5_S1': 5,
#  'cropped_images_detailed/1382950184/Sagittal T1/L4_L5': 4,
#  'cropped_images_detailed/1382950184/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1382950184/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1382950184/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1383495058/Sagittal T1/L5_S1': 13,
#  'cropped_images_detailed/1383495058/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1383495058/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1383495058/Sagittal T1/L2_L3': 8,
#  'cropped_images_detailed/1383495058/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1384039220/Sagittal T1/L5_S1': 10,
#  'cropped_images_detailed/1384039220/Sagittal T1/L4_L5': 8,
#  'cropped_images_detailed/1384039220/Sagittal T1/L3_L4': 3,
#  'cropped_images_detailed/1384039220/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1384039220/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1387631768/Sagittal T1/L5_S1': 15,
#  'cropped_images_detailed/1387631768/Sagittal T1/L4_L5': 9,
#  'cropped_images_detailed/1387631768/Sagittal T1/L3_L4': 7,
#  'cropped_images_detailed/1387631768/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1387631768/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1388399428/Sagittal T1/L5_S1': 9,
#  'cropped_images_detailed/1388399428/Sagittal T1/L4_L5': 7,
#  'cropped_images_detailed/1388399428/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1388399428/Sagittal T1/L1_L2': 8,
#  'cropped_images_detailed/1388399428/Sagittal T1/L2_L3': 5,
#  'cropped_images_detailed/1395246421/Sagittal T1/L5_S1': 17,
#  'cropped_images_detailed/1395246421/Sagittal T1/L4_L5': 14,
#  'cropped_images_detailed/1395246421/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1395246421/Sagittal T1/L1_L2': 7,
#  'cropped_images_detailed/1395246421/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1395773918/Sagittal T1/L5_S1': 12,
#  'cropped_images_detailed/1395773918/Sagittal T1/L3_L4': 9,
#  'cropped_images_detailed/1395773918/Sagittal T1/L2_L3': 6,
#  'cropped_images_detailed/1395773918/Sagittal T1/L4_L5': 10,
#  'cropped_images_detailed/1395773918/Sagittal T1/L1_L2': 4,
#  'cropped_images_detailed/1400326269/Sagittal T1/L5_S1': 7,
#  'cropped_images_detailed/1400326269/Sagittal T1/L4_L5': 6,
#  'cropped_images_detailed/1400326269/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1400326269/Sagittal T1/L2_L3': 3,
#  'cropped_images_detailed/1400326269/Sagittal T1/L3_L4': 2,
#  'cropped_images_detailed/1406734395/Sagittal T1/L5_S1': 17,
#  'cropped_images_detailed/1406734395/Sagittal T1/L4_L5': 13,
#  'cropped_images_detailed/1406734395/Sagittal T1/L3_L4': 5,
#  'cropped_images_detailed/1406734395/Sagittal T1/L1_L2': 5,
#  'cropped_images_detailed/1406734395/Sagittal T1/L2_L3': 4,
#  ...}
